# %% [markdown]
# # HEALTH CARE PROJECT

# %%
import pandas as pd, matplotlib.pyplot as plt, seaborn as sns

# %%
df=pd.read_excel("1645792390_cep1_dataset.xlsx")

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 298    False
# 299    False
# 300    False
# 301    False
# 302    False
# Length: 303, dtype: bool

# %%
df_new=df.drop_duplicates()

# %%
df_new
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %% [markdown]
# ## The one duplicated row is droped.

# %%
df_new.nunique()
# Out:
# age          41
# sex           2
# cp            4
# trestbps     49
# chol        152
# fbs           2
# restecg       3
# thalach      91
# exang         2
# oldpeak      40
# slope         3
# ca            5
# thal          4
# target        2
# dtype: int64

# %%
df_new.target.value_counts()
# Out:
# 1    164
# 0    138
# Name: target, dtype: int64

# %%
df_new.cp.value_counts()
# Out:
# 0    143
# 2     86
# 1     50
# 3     23
# Name: cp, dtype: int64

# %%
df_new.fbs.value_counts()
# Out:
# 0    257
# 1     45
# Name: fbs, dtype: int64

# %%
df_new.restecg.value_counts()
# Out:
# 1    151
# 0    147
# 2      4
# Name: restecg, dtype: int64

# %%
df_new.exang.value_counts()
# Out:
# 0    203
# 1     99
# Name: exang, dtype: int64

# %%
df_new.slope.value_counts()
# Out:
# 2    141
# 1    140
# 0     21
# Name: slope, dtype: int64

# %%
df_new.ca.value_counts()
# Out:
# 0    175
# 1     65
# 2     38
# 3     20
# 4      4
# Name: ca, dtype: int64

# %%
df_new.thal.value_counts()
# Out:
# 2    165
# 3    117
# 1     18
# 0      2
# Name: thal, dtype: int64

# %%
matrix=df_new.corr().round(2)

# %%
matrix
# Out:
#            age   sex    cp  trestbps  chol   fbs  restecg  thalach  exang  \
# age       1.00 -0.09 -0.06      0.28  0.21  0.12    -0.11    -0.40   0.09
# sex      -0.09  1.00 -0.05     -0.06 -0.20  0.05    -0.06    -0.05   0.14
# cp       -0.06 -0.05  1.00      0.05 -0.07  0.10     0.04     0.29  -0.39
# trestbps  0.28 -0.06  0.05      1.00  0.13  0.18    -0.12    -0.05   0.07
# chol      0.21 -0.20 -0.07      0.13  1.00  0.01    -0.15    -0.01   0.06
# fbs       0.12  0.05  0.10      0.18  0.01  1.00    -0.08    -0.01   0.02
# restecg  -0.11 -0.06  0.04     -0.12 -0.15 -0.08     1.00     0.04  -0.07
# thalach  -0.40 -0.05  0.29     -0.05 -0.01 -0.01     0.04     1.00  -0.38
# exang     0.09  0.14 -0.39      0.07  0.06  0.02    -0.07    -0.38   1.00
# oldpeak   0.21  0.10 -0.15      0.19  0.05  0.00    -0.06    -0.34   0.29
# slope    -0.16 -0.03  0.12     -0.12  0.00 -0.06     0.09     0.38  -0.26
# ca        0.30  0.11 -0.20      0.10  0.09  0.14    -0.08    -0.23   0.13
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(matrix, annot=True, vmin=-1, vmax=1, center=0, cmap="YlGnBu", linewidth=2)
plt.show()

# %% [markdown]
# ## As we can see that there is a positive correlation between chest pain , thalach (independent variables) and target (independent variable).
#
# ## And a negative correlation between exercise induced angina (exang), oldpeak (independent variables) and target (independent variable).
#
# ## There also exist some correlations between the independent variables as thalach with cp and slope.

# %% [markdown]
# ## UNIVARIATE ANALYSIS

# %%
plt.figure(figsize=(30,10))
plt.subplot(1,2,1)
sns.countplot(x='age', data=df_new)
plt.xlabel("age")
plt.subplot(1,2,2)
sns.countplot(x='oldpeak', data=df_new)
plt.xlabel("oldpeak")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize = (30,10))
plt.subplot(1,7,1)
sns.countplot(x='sex', data=df_new)
plt.xlabel("Sex (0 = female, 1= male)")
plt.subplot(1,7,2)
sns.countplot(x='cp', data=df_new)
plt.xlabel("chest pain")
plt.subplot(1,7,3)
sns.countplot(x='exang', data=df_new)
plt.xlabel("excersise induced angina 0=no, 1=yes")
plt.subplot(1,7,4)
sns.countplot(x='slope', data=df_new)
plt.xlabel("slope")
plt.subplot(1,7,5)
sns.countplot(x='ca', data=df_new)
plt.xlabel("ca")
plt.subplot(1,7,6)
sns.countplot(x='thal', data=df_new)
plt.xlabel("thal")
plt.subplot(1,7,7)
sns.countplot(x='fbs', data=df_new)
plt.xlabel("fbs")
plt.show()

# %%
plt.figure(figsize = (30,15))
plt.subplot(3,1,1)
sns.countplot(x='trestbps', data=df_new)
plt.xlabel("trestbps")
plt.subplot(3,1,2)
sns.countplot(x='restecg', data=df_new)
plt.xlabel("restecg")
plt.subplot(3,1,3)
sns.countplot(x='chol', data=df_new)
plt.xlabel("chol")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.countplot(x='thalach', data=df_new)
plt.xlabel("thalach")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## BIVARIATE ANALYSIS

# %%
pd.crosstab(df_new.age,df_new.target).plot(kind="bar",figsize=(20,10))
plt.title('Heart Disease Frequency for Ages')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
pd.crosstab(df_new.sex,df_new.target).plot(kind="bar",figsize=(5,5))
plt.title('Heart Disease Frequency for Sex')
plt.xlabel('Sex (0 = Female, 1 = Male)')
plt.ylabel('Frequency')
plt.legend(["Haven't Disease", "Have Disease"])
plt.xticks(rotation=0)
# Out:
# (array([0, 1]), [Text(0, 0, '0'), Text(1, 0, '1')])

# %%
plt.figure(figsize=(10,5))
plt.scatter(x=df_new.age[df_new.target==1], y=df_new.thalach[(df_new.target==1)], c="red")
plt.scatter(x=df_new.age[df_new.target==0], y=df_new.thalach[(df_new.target==0)])
plt.legend(["Disease", "Not Disease"])
plt.xlabel("Age")
plt.ylabel("Maximum Heart Rate")
plt.show()

# %%
pd.crosstab(df_new.slope,df_new.target).plot(kind="bar", figsize=(5,5))
plt.title('Heart Disease Frequency for Slope')
plt.xlabel('The Slope of The Peak Exercise ST Segment ')
plt.xticks(rotation = 0)
plt.ylabel('Frequency')
plt.show()

# %%
pd.crosstab(df_new.fbs,df_new.target).plot(kind="bar", figsize=(5,5))
plt.title('Heart Disease Frequency According To FBS')
plt.xlabel('FBS - (Fasting Blood Sugar > 120 mg/dl) (1 = true; 0 = false)')
plt.xticks(rotation = 0)
plt.legend(["Haven't Disease", "Have Disease"])
plt.ylabel('Frequency of Disease or Not')
plt.show()

# %%
pd.crosstab(df_new.cp,df_new.target).plot(kind="bar", figsize=(5,5))
plt.title('Heart Disease Frequency According To Chest Pain Type')
plt.xlabel('Chest Pain Type')
plt.xticks(rotation = 0)
plt.ylabel('Frequency of Disease or Not')
plt.show()

# %%
data=df_new[["trestbps", "chol", "restecg", "exang", "oldpeak", "ca", "thal", "target"]]
g=sns.PairGrid(data, hue="target", vars=["trestbps", "chol", "restecg", "exang", "oldpeak", "ca", "thal"])
g.map_diag(sns.histplot, kde=True)
g.map_offdiag(sns.scatterplot)
g.add_legend()

# %%
data1=df_new[["age", "sex", "cp", "thalach", "slope", "fbs", "target"]]
g=sns.PairGrid(data1, hue="target", vars=["age", "sex", "cp", "thalach", "slope", "fbs"])
g.map_diag(sns.histplot, kde=True)
g.map_offdiag(sns.scatterplot)
g.add_legend()

# %% [markdown]
# ## Class Distribution

# %%
maj_data = df_new[df_new["target"]==1]
maj_data.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  164.000000  164.000000  164.000000  164.000000  164.000000  164.000000
# mean    52.585366    0.560976    1.371951  129.250000  242.640244    0.140244
# std      9.511957    0.497788    0.953878   16.204739   53.456580    0.348303
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     44.750000    0.000000    1.000000  120.000000  208.750000    0.000000
# 50%     52.000000    1.000000    2.000000  130.000000  234.500000    0.000000
# 75%     59.000000    1.000000    2.000000  140.000000  267.250000    0.000000
# max     76.000000    1.000000    3.000000  180.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  164.000000  164.000000  164.000000  164.000000  164.000000  164.000000
# mean     0.591463  158.378049    0.140244    0.586585    1.591463    0.341463
# ...

# %%
maj_data.shape
# Out:
# (164, 14)

# %%
min_data = df_new[df_new['target']==0]
min_data.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  138.000000  138.000000  138.000000  138.000000  138.000000  138.000000
# mean    56.601449    0.826087    0.478261  134.398551  251.086957    0.159420
# std      7.962082    0.380416    0.905920   18.729944   49.454614    0.367401
# min     35.000000    0.000000    0.000000  100.000000  131.000000    0.000000
# 25%     52.000000    1.000000    0.000000  120.000000  217.250000    0.000000
# 50%     58.000000    1.000000    0.000000  130.000000  249.000000    0.000000
# 75%     62.000000    1.000000    0.000000  144.750000  283.000000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  409.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  138.000000  138.000000  138.000000  138.000000  138.000000  138.000000
# mean     0.449275  139.101449    0.550725    1.585507    1.166667    1.166667
# ...

# %%
min_data.shape
# Out:
# (138, 14)

# %% [markdown]
# ## A balanced dataset but i still required a complete 50-50 balanced dataset for less errored classification

# %% [markdown]
# # MODEL BUILDING

# %%
from imblearn.over_sampling import SVMSMOTE
from collections import Counter

# %%
x=df_new.drop('target', axis=1)
y=df_new.target

# %%
x.shape
# Out:
# (302, 13)

# %%
y.shape
# Out:
# (302,)

# %%
oversample=SVMSMOTE(random_state=42)
X, Y=oversample.fit_resample(x,y)
counter=Counter(Y)
counter
# Out:
# Counter({1: 164, 0: 164})

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(X,Y,test_size = 0.1, random_state=100)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
from sklearn.metrics import classification_report 
from sklearn.linear_model import LogisticRegression

# %%
model1 = LogisticRegression(random_state=100)
model1.fit(x_train, y_train)
y_pred1 = model1.predict(x_test)
print(classification_report(y_test, y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.88      0.94        17
#            1       0.89      1.00      0.94        16
#
#     accuracy                           0.94        33
#    macro avg       0.94      0.94      0.94        33
# weighted avg       0.95      0.94      0.94        33

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model2 = DecisionTreeClassifier(random_state=100)
model2.fit(x_train, y_train)
y_pred2 = model2.predict(x_test)
print(classification_report(y_test, y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.76      0.84        17
#            1       0.79      0.94      0.86        16
#
#     accuracy                           0.85        33
#    macro avg       0.86      0.85      0.85        33
# weighted avg       0.86      0.85      0.85        33

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model3 = RandomForestClassifier(random_state=100)
model3.fit(x_train, y_train)
y_pred3 = model3.predict(x_test)
print(classification_report(y_test, y_pred3))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.88      0.94        17
#            1       0.89      1.00      0.94        16
#
#     accuracy                           0.94        33
#    macro avg       0.94      0.94      0.94        33
# weighted avg       0.95      0.94      0.94        33

# %% [markdown]
# ## Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
cm = confusion_matrix(y_test, y_pred1)
print(cm)
accuracy_score(y_test, y_pred1)
# Out:
# [[15  2]
#  [ 0 16]]
# 0.9393939393939394

# %% [markdown]
# ## 15 is the amount of True Positives in our data, while 16 is the amount of True Negatives.
#
# ## 2 - Type 1 errors (False Positives) and 0 - Type 2 errors (False Negatives).

# %% [markdown]
# ## Feature Importance

# %%
importance = model3.feature_importances_
for i,v in enumerate(importance):
    print('Feature: %0d, Score: %.5f' % (i,v))
# Out:
# Feature: 0, Score: 0.08871
# Feature: 1, Score: 0.03435
# Feature: 2, Score: 0.14763
# Feature: 3, Score: 0.08342
# Feature: 4, Score: 0.08893
# Feature: 5, Score: 0.01035
# Feature: 6, Score: 0.02168
# Feature: 7, Score: 0.11384
# Feature: 8, Score: 0.03533
# Feature: 9, Score: 0.09888
# Feature: 10, Score: 0.05471
# Feature: 11, Score: 0.11801
# Feature: 12, Score: 0.10417

# %%
index=df_new.columns[:-1]
importance = pd.Series(model3.feature_importances_, index=index)
importance.nlargest(13).plot(kind='barh', colormap='winter', figsize=(15,15))
# Out:
# <AxesSubplot: >
